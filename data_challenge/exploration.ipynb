# %%
import pandas as pd

# %%
# read csv file
df = pd.read_csv('Train.csv')
df
# Out:
#                     responseId       view_label  \
# 0      zYkHaeOdB7XOnvgP3YW5kQs  Norman Niles #1
# 1      NYsHaeCRLq-vnvgPjoXZqA0  Norman Niles #1
# 2      A40HaYT8KNm7nvgPq8e12AU  Norman Niles #1
# 3      EIsHaanDMK-vnvgPjoXZqA0  Norman Niles #1
# 4      RYsHafSeMaqpmecP5vCV0AQ  Norman Niles #1
# ...                        ...              ...
# 16071  0YkHacyJMq-vnvgPjoXZqA0  Norman Niles #4
# 16072  PYoHaan6Lb-envgP6uGTmAE  Norman Niles #4
# 16073  7ooHafDLFdP_ld8Piv3HsQo  Norman Niles #4
# 16074  0okHabnnG-K2nvgPsZGZ4Aw  Norman Niles #4
# 16075  aYwHae2SDrXOnvgP3YW5kQs  Norman Niles #4
#
#                                                 ID_enter  \
# 0      time_segment_0_Norman Niles #1_congestion_ente...
# 1      time_segment_1_Norman Niles #1_congestion_ente...
# 2      time_segment_2_Norman Niles #1_congestion_ente...
# 3      time_segment_3_Norman Niles #1_congestion_ente...
# 4      time_segment_4_Norman Niles #1_congestion_ente...
# ...

# %%
df[df["date"] == "2025-10-20"]
# Out:
#                     responseId       view_label  \
# 0      zYkHaeOdB7XOnvgP3YW5kQs  Norman Niles #1
# 1      NYsHaeCRLq-vnvgPjoXZqA0  Norman Niles #1
# 2      A40HaYT8KNm7nvgPq8e12AU  Norman Niles #1
# 3      EIsHaanDMK-vnvgPjoXZqA0  Norman Niles #1
# 4      RYsHafSeMaqpmecP5vCV0AQ  Norman Niles #1
# ...                        ...              ...
# 12633   IYsHad1rn__r3w_B5ZqJDg  Norman Niles #4
# 12634  0YkHabmCE6HXnvgP76fxyQI  Norman Niles #4
# 12635  d4sHacrSIbmfnvgPoaTSqQ0  Norman Niles #4
# 12636  DY0Hab2AGNCT3NoP8rPIoA0  Norman Niles #4
# 12637  zYkHacmCK7Ov3NoPq7G46QE  Norman Niles #4
#
#                                                 ID_enter  \
# 0      time_segment_0_Norman Niles #1_congestion_ente...
# 1      time_segment_1_Norman Niles #1_congestion_ente...
# 2      time_segment_2_Norman Niles #1_congestion_ente...
# 3      time_segment_3_Norman Niles #1_congestion_ente...
# 4      time_segment_4_Norman Niles #1_congestion_ente...
# ...

# %%
df[df["date"] == "2025-10-20"][["view_label", "congestion_enter_rating", "congestion_exit_rating", "signaling", ]]
# Out:
#             view_label congestion_enter_rating congestion_exit_rating  \
# 0      Norman Niles #1            free flowing           free flowing
# 1      Norman Niles #1            free flowing           free flowing
# 2      Norman Niles #1            free flowing           free flowing
# 3      Norman Niles #1            free flowing           free flowing
# 4      Norman Niles #1            free flowing           free flowing
# ...                ...                     ...                    ...
# 12633  Norman Niles #4            free flowing           free flowing
# 12634  Norman Niles #4             light delay           free flowing
# 12635  Norman Niles #4            free flowing           free flowing
# 12636  Norman Niles #4             heavy delay           free flowing
# 12637  Norman Niles #4            free flowing           free flowing
#
#       signaling
# 0          none
# 1          none
# 2          none
# 3          none
# 4          none
# ...         ...
# ...

# %%
df[0:1].to_dict()
# Out:
# {'responseId': {0: 'zYkHaeOdB7XOnvgP3YW5kQs'},
#  'view_label': {0: 'Norman Niles #1'},
#  'ID_enter': {0: 'time_segment_0_Norman Niles #1_congestion_enter_rating'},
#  'ID_exit': {0: 'time_segment_0_Norman Niles #1_congestion_exit_rating'},
#  'videos': {0: 'normanniles1/normanniles1_2025-10-20-06-00-45.mp4'},
#  'video_time': {0: '2025-10-20 06:00:45'},
#  'datetimestamp_start': {0: '2025-10-20 06:00:45'},
#  'datetimestamp_end': {0: '2025-10-20 06:01:44'},
#  'date': {0: '2025-10-20'},
#  'signaling': {0: 'none'},
#  'congestion_enter_rating': {0: 'free flowing'},
#  'congestion_exit_rating': {0: 'free flowing'},
#  'time_segment_id': {0: 0},
#  'cycle_phase': {0: 'train'}}
